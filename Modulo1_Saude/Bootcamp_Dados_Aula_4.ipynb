# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickOlivetto/bootcamp-data-science-aplicada/blob/main/Modulo1_Saude/Bootcamp_Dados_Aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
pd.options.display.float_format = '{:.2f}'.format

# %%
dados = pd.read_csv("https://github.com/ErickOlivetto/bootcamp-data-science-aplicada/raw/main/Dados/A120703189_28_143_208.csv", encoding='ISO-8859-1', skiprows=3, sep = ';', skipfooter=12, thousands='.', decimal=',', engine='python')

# %%
usaveis = dados.mean().index.tolist()
usaveis.insert(0, 'Unidade da Federação')
dados_usaveis = dados[usaveis]
dados_usaveis = dados_usaveis.set_index('Unidade da Federação')
dados_usaveis = dados_usaveis.drop('Total', axis=1)
dados_usaveis['Total'] = dados_usaveis.sum(axis=1)
ordenados_total = dados_usaveis.sort_values('Total', ascending = False)
ordenados_total = ordenados_total.drop('Total', axis = 1)
colunas_interesse = ordenados_total.columns[6:]
ordenados_total = ordenados_total[colunas_interesse]
regioes = {'1':'Norte', '2':'Nordeste', '3':'Sudeste', '4':'Sul', '5':'Centro-Oeste'}
ordenados_total['Região'] = [regioes[dado[0]] for dado in ordenados_total.index]

# %% [markdown]
# #Aula 4

# %%
ordenados_total = ordenados_total.drop('Região', axis = 1)
ordenados_total = ordenados_total/1000000
ax = ordenados_total.head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus a partir de Fev/2008 para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
plt.show()

# %%
periodo_plotado = ordenados_total.columns[47:155]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus entre Jan/2012 e Dez/2020 para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
plt.show()

# %%
periodo_plotado = ordenados_total.columns[47:155]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus entre Jan/2012 e Dez/2020 para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[47:155]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus entre Jan/2012 e Dez/2020 para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(100,350)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[-12:]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[-24:]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[-36:]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[-60:]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(12,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[47:155]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(8,8), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus entre Jan/2012 e Dez/2020 para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()

# %%
periodo_plotado = ordenados_total.columns[47:155]
ax = ordenados_total[periodo_plotado].head().T.plot(figsize=(25,6), legend = False, colormap = 'rainbow')
ax.legend(bbox_to_anchor=(1, 1), loc = 'upper left')
ax.set_title('Evolução do valor total por mês de atendimento no sus entre Jan/2012 e Dez/2020 para as 5 regiões com maior gasto acumulado')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
ax.set_xlabel('Mês de atendimento')
ax.set_ylabel('Gastos por mês em milhões de reais [Milhões R$]')
ax.set_ylim(0,400)
plt.show()
